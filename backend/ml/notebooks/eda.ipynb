# %%
import pandas as pd

# %%
df= pd.read_csv('../data/complaints.csv')

# %%
df.head()
# Out:
#   ComplaintID                                          Complaint  Category  \
# 0   CMP_10001  The indoor gym equipment cable snapped while a...    Sports
# 1   CMP_10002  The authentication gateway server is down, pre...  Internet
# 2   CMP_10003  A large chunk of plaster fell from the ceiling...    Hostel
# 3   CMP_10004  the exam paper leaked online an hour prior to ...  Academic
# 4   CMP_10005  Rainwater is rally leaking from the roof direc...   Library
#
#     Urgency
# 0      High
# 1      High
# 2  Critical
# 3      High
# 4      High

# %%
df.shape
# Out:
# (5000, 4)

# %%
df.isna().sum()
# Out:
# ComplaintID    0
# Complaint      0
# Category       0
# Urgency        0
# dtype: int64

# %%
df.describe()
# Out:
#        ComplaintID                                          Complaint  \
# count         5000                                               5000
# unique        5000                                               1124
# top      CMP_10001  A major collision involving the university tra...
# freq             1                                                 58
#
#         Category Urgency
# count       5000    5000
# unique        12       4
# top     Internet     Low
# freq         417    1372

# %%
df['Category'].value_counts()
# Out:
# Category
# Internet       417
# Hostel         417
# Library        417
# Electricity    417
# Transport      417
# Laboratory     417
# Plumbing       417
# Mess           417
# Sports         416
# Academic       416
# Medical        416
# Security       416
# Name: count, dtype: int64

# %%
df['Urgency'].value_counts()
# Out:
# Urgency
# Low         1372
# High        1234
# Critical    1197
# Medium      1197
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ComplaintID  5000 non-null   str
#  1   Complaint    5000 non-null   str
#  2   Category     5000 non-null   str
#  3   Urgency      5000 non-null   str
# dtypes: str(4)
# memory usage: 156.4 KB
